# %% [markdown]
# # Handwritten Digit Recognition
#
# This tutorial guides you through a classic computer vision application: identify hand written digits with neural networks.
#
# ## Load data
#
# We first fetch the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, which is a commonly used dataset for handwritten digit recognition. Each image in this dataset has been resized into 28x28 with grayscale value between 0 and 254. The following codes download and load the images and the according labels into `numpy`.

# %%
import numpy as np
import os
import urllib
import gzip
import struct
def download_data(url, force_download=True): 
    fname = url.split("/")[-1]
    if force_download or not os.path.exists(fname):
        urllib.urlretrieve(url, fname)
    return fname

def read_data(label_url, image_url):
    with gzip.open(download_data(label_url)) as flbl:
        magic, num = struct.unpack(">II", flbl.read(8))
        label = np.fromstring(flbl.read(), dtype=np.int8)
    with gzip.open(download_data(image_url), 'rb') as fimg:
        magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
        image = np.fromstring(fimg.read(), dtype=np.uint8).reshape(len(label), rows, cols)
    return (label, image)

path='http://yann.lecun.com/exdb/mnist/'
(train_lbl, train_img) = read_data(
    path+'train-labels-idx1-ubyte.gz', path+'train-images-idx3-ubyte.gz')
(val_lbl, val_img) = read_data(
    path+'t10k-labels-idx1-ubyte.gz', path+'t10k-images-idx3-ubyte.gz')

# %% [markdown]
# We plot the first 10 images and print their labels.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(train_img[i], cmap='Greys_r')
    plt.axis('off')
plt.show()
print('label: %s' % (train_lbl[0:10],))
# Out:
# label: [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# Next we create data iterators for MXNet. The data iterator, which is similar the iterator, returns a batch of data in each `next()` call. A batch contains several images with its according labels. These images are stored in a 4-D matrix with shape `(batch_size, num_channels, width, height)`. For the MNIST dataset, there is only one color channel, and both width and height are 28. In addition, we often shuffle the images used for training, which accelerates the training progress.

# %%
import mxnet as mx

def to4d(img):
    return img.reshape(img.shape[0], 1, 28, 28).astype(np.float32)/255

batch_size = 100
train_iter = mx.io.NDArrayIter(to4d(train_img), train_lbl, batch_size, shuffle=True)
val_iter = mx.io.NDArrayIter(to4d(val_img), val_lbl, batch_size)

# %% [markdown]
# ## Multilayer Perceptron
#
# A multilayer perceptron contains several fully-connected layers. A fully-connected layer, with an *n x m* input matrix *X* outputs a matrix *Y* with size *n x k*, where *k* is often called as the hidden size. This layer has two parameters, the *m x k* weight matrix *W* and the *m x 1* bias vector *b*. It compute the outputs with
#
# $$Y = W X + b.$$
#
# The output of a fully-connected layer is often feed into an activation layer, which performs element-wise operations. Two common options are the sigmoid function, or the rectifier (or "relu") function, which outputs the max of 0 and the input.
#
# The last fully-connected layer often has the hidden size equals to the number of classes in the dataset. Then we stack a softmax layer, which map the input into a probability score. Again assume the input *X* has size *n x m*:
#
# $$ \left[\frac{\exp(x_{i1})}{\sum_{j=1}^m \exp(x_{ij})},\ldots, \frac{\exp(x_{im})}{\sum_{j=1}^m \exp(x_{ij})}\right] $$
#
# Defining the multilayer perceptron in MXNet is straightforward, which has shown as following.

# %%
# Create a place holder variable for the input data
data = mx.sym.Variable('data')
# Flatten the data from 4-D shape (batch_size, num_channel, width, height) 
# into 2-D (batch_size, num_channel*width*height)
data = mx.sym.Flatten(data=data)

# The first fully-connected layer
fc1  = mx.sym.FullyConnected(data=data, name='fc1', num_hidden=128)
# Apply relu to the output of the first fully-connnected layer
act1 = mx.sym.Activation(data=fc1, name='relu1', act_type="relu")

# The second fully-connected layer and the according activation function
fc2  = mx.sym.FullyConnected(data=act1, name='fc2', num_hidden = 64)
act2 = mx.sym.Activation(data=fc2, name='relu2', act_type="relu")

# The thrid fully-connected layer, note that the hidden size should be 10, which is the number of unique digits
fc3  = mx.sym.FullyConnected(data=act2, name='fc3', num_hidden=10)
# The softmax and loss layer
mlp  = mx.sym.SoftmaxOutput(data=fc3, name='softmax')

# We visualize the network structure with output size (the batch_size is ignored.)
shape = {"data" : (batch_size, 1, 28, 28)}
mx.viz.plot_network(symbol=mlp, shape=shape)

# %% [markdown]
# Now both the network definition and data iterators are ready. We can start training.

# %%
# @@@ AUTOTEST_OUTPUT_IGNORED_CELL
import logging
logging.getLogger().setLevel(logging.DEBUG)

model = mx.model.FeedForward(
    symbol = mlp,       # network structure
    num_epoch = 10,     # number of data passes for training 
    learning_rate = 0.1 # learning rate of SGD 
)
model.fit(
    X=train_iter,       # training data
    eval_data=val_iter, # validation data
    batch_end_callback = mx.callback.Speedometer(batch_size, 200) # output progress for each 200 data batches
)
# Out:
# /Users/jon/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#
# /Users/jon/anaconda/lib/python2.7/site-packages/mxnet/model.py:547: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
#   self.initializer(k, v)
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [200]	Speed: 76794.28 samples/sec	accuracy=0.109450
# INFO:root:Epoch[0] Batch [400]	Speed: 91887.25 samples/sec	accuracy=0.112200
# INFO:root:Epoch[0] Batch [600]	Speed: 71773.57 samples/sec	accuracy=0.133100
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=0.762
# INFO:root:Epoch[0] Validation-accuracy=0.235700
# INFO:root:Epoch[1] Batch [200]	Speed: 88574.32 samples/sec	accuracy=0.417650
# INFO:root:Epoch[1] Batch [400]	Speed: 67191.91 samples/sec	accuracy=0.745350
# INFO:root:Epoch[1] Batch [600]	Speed: 85467.92 samples/sec	accuracy=0.826050
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=0.762
# INFO:root:Epoch[1] Validation-accuracy=0.848200
# INFO:root:Epoch[2] Batch [200]	Speed: 66231.53 samples/sec	accuracy=0.857400
# INFO:root:Epoch[2] Batch [400]	Speed: 89687.33 samples/sec	accuracy=0.887700
# INFO:root:Epoch[2] Batch [600]	Speed: 87425.96 samples/sec	accuracy=0.903450
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=0.760
# INFO:root:Epoch[2] Validation-accuracy=0.906500
# INFO:root:Epoch[3] Batch [200]	Speed: 83092.71 samples/sec	accuracy=0.913250
# INFO:root:Epoch[3] Batch [400]	Speed: 90958.27 samples/sec	accuracy=0.929450
# INFO:root:Epoch[3] Batch [600]	Speed: 89310.82 samples/sec	accuracy=0.933700
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=0.690
# INFO:root:Epoch[3] Validation-accuracy=0.935000
# INFO:root:Epoch[4] Batch [200]	Speed: 84188.15 samples/sec	accuracy=0.938600
# INFO:root:Epoch[4] Batch [400]	Speed: 90093.72 samples/sec	accuracy=0.949300
# INFO:root:Epoch[4] Batch [600]	Speed: 91512.65 samples/sec	accuracy=0.948700
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=0.683
# INFO:root:Epoch[4] Validation-accuracy=0.948400
# INFO:root:Epoch[5] Batch [200]	Speed: 90348.92 samples/sec	accuracy=0.952600
# INFO:root:Epoch[5] Batch [400]	Speed: 90946.73 samples/sec	accuracy=0.958900
# INFO:root:Epoch[5] Batch [600]	Speed: 65016.73 samples/sec	accuracy=0.958200
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=0.753
# INFO:root:Epoch[5] Validation-accuracy=0.956400
# INFO:root:Epoch[6] Batch [200]	Speed: 91950.61 samples/sec	accuracy=0.960600
# INFO:root:Epoch[6] Batch [400]	Speed: 91099.13 samples/sec	accuracy=0.966600
# INFO:root:Epoch[6] Batch [600]	Speed: 91732.11 samples/sec	accuracy=0.963650
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=0.660
# INFO:root:Epoch[6] Validation-accuracy=0.959700
# INFO:root:Epoch[7] Batch [200]	Speed: 85103.14 samples/sec	accuracy=0.967150
# INFO:root:Epoch[7] Batch [400]	Speed: 95734.57 samples/sec	accuracy=0.970650
# INFO:root:Epoch[7] Batch [600]	Speed: 94012.34 samples/sec	accuracy=0.967900
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=0.662
# INFO:root:Epoch[7] Validation-accuracy=0.963300
# INFO:root:Epoch[8] Batch [200]	Speed: 77230.51 samples/sec	accuracy=0.971300
# INFO:root:Epoch[8] Batch [400]	Speed: 95975.76 samples/sec	accuracy=0.974900
# INFO:root:Epoch[8] Batch [600]	Speed: 94078.66 samples/sec	accuracy=0.972700
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=0.686
# INFO:root:Epoch[8] Validation-accuracy=0.965900
# INFO:root:Epoch[9] Batch [200]	Speed: 81628.00 samples/sec	accuracy=0.975150
# INFO:root:Epoch[9] Batch [400]	Speed: 92859.56 samples/sec	accuracy=0.978100
# INFO:root:Epoch[9] Batch [600]	Speed: 74226.60 samples/sec	accuracy=0.975900
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=0.735
# INFO:root:Epoch[9] Validation-accuracy=0.968100

# %% [markdown]
# After training is done, we can predict a single image.

# %%
# @@@ AUTOTEST_OUTPUT_IGNORED_CELL
plt.imshow(val_img[0], cmap='Greys_r')
plt.axis('off')
plt.show()
prob = model.predict(val_img[0:1].astype(np.float32)/255)[0]
assert max(prob) > 0.99, "Low prediction accuracy."
print 'Classified as %d with probability %f' % (prob.argmax(), max(prob))
# Out:
# Classified as 7 with probability 0.999655

# %% [markdown]
# We can also evaluate the accuracy given a data iterator.

# %%
# @@@ AUTOTEST_OUTPUT_IGNORED_CELL
valid_acc = model.score(val_iter)
print 'Validation accuracy: %f%%' % (valid_acc *100,)
assert valid_acc > 0.95, "Low validation accuracy."
# Out:
# Validation accuracy: 96.810000%

# %% [markdown]
# Even more, we can recognizes the digit written on the below box.

# %%
from IPython.display import HTML
import cv2
import numpy as np

def classify(img):
    img = img[len('data:image/png;base64,'):].decode('base64')
    img = cv2.imdecode(np.fromstring(img, np.uint8), -1)
    img = cv2.resize(img[:,:,3], (28,28))
    img = img.astype(np.float32).reshape((1,1,28,28))/255.0
    return model.predict(img)[0].argmax()

'''
To see the model in action, run the demo notebook at
https://github.com/dmlc/mxnet-notebooks/blob/master/python/tutorials/mnist.ipynb.
'''
HTML(filename="mnist_demo.html")
# Out:
# <style type="text/css">
#   canvas { border: 1px solid black; }
# </style>
#
# <div id="board">
#
#   <canvas id="myCanvas" width="100px" height="100px">
#     Sorry, your browser doesn't support canvas technology.
#   </canvas>
#
#   <p>
#
#     <button id="classify" onclick="classify()">
#       Classify
#     </button>
#
#     <button id="clear" onclick="myClear()">
#       Clear
#     </button>
#     Result:
#     <input type="text" id="result_output" size="5" value="">
#
#   </p>
#
# </div>
#
# <script type = "text/JavaScript" src = "https://ajax.googleapis.com/ajax/libs/jquery/1.4.2/jquery.min.js?ver=1.4.2" > </script>
#
# <script type = "text/javascript" >
#
#     function init() {
#         var myCanvas = document.getElementById("myCanvas");
#         var curColor = $('#selectColor option:selected').val();
#         if (myCanvas) {
#             var isDown = false;
#             var ctx = myCanvas.getContext("2d");
#             var canvasX, canvasY;
#             ctx.lineWidth = 8;
#             $(myCanvas).mousedown(function(e) {
#                 isDown = true;
#                 ctx.beginPath();
#                 var parentOffset = $(this).parent().offset();
#                 canvasX = e.pageX - parentOffset.left;
#                 canvasY = e.pageY - parentOffset.top;
#                 ctx.moveTo(canvasX, canvasY);
#             }).mousemove(function(e) {
#                 if (isDown != false) {
#                     var parentOffset = $(this).parent().offset();
#                     canvasX = e.pageX - parentOffset.left;
#                     canvasY = e.pageY - parentOffset.top;
#                     ctx.lineTo(canvasX, canvasY);
#                     ctx.strokeStyle = curColor;
#                     ctx.stroke();
#                 }
#             }).mouseup(function(e) {
#                 isDown = false;
#                 ctx.closePath();
#             });
#         }
#         $('#selectColor').change(function() {
#             curColor = $('#selectColor option:selected').val();
#         });
#     }
# init();
#
# function handle_output(out) {
#     console.log(out)
#     document.getElementById("result_output").value = out.content.data["text/plain"];
# }
#
# function classify() {
#     var kernel = IPython.notebook.kernel;
#     var myCanvas = document.getElementById("myCanvas");
#     data = myCanvas.toDataURL('image/png');
#     document.getElementById("result_output").value = "";
#     kernel.execute("classify('" + data + "')", {
#         'iopub': {
#             'output': handle_output
#         }
#     }, {
#         silent: false
#     });
# }
#
# function myClear() {
#     var myCanvas = document.getElementById("myCanvas");
#     myCanvas.getContext("2d").clearRect(0, 0, myCanvas.width, myCanvas.height);
# }
#
#
# </script>

# %% [markdown]
# ## Convolutional Neural Networks
#
# Note that the previous fully-connected layer simply reshapes the image into a vector during training. It ignores the spatial information that pixels are correlated on both horizontal and vertical dimensions. The convolutional layer aims to improve this drawback by using a more structural weight $W$. Instead of simply matrix-matrix multiplication, it uses 2-D convolution to obtain the output.

# %% [markdown]
# <img src="https://thatindiandude.github.io/images/conv.png" style="height: 75%; width: 75%;">

# %% [markdown]
# We can also have multiple feature maps, each with their own weight matrices, to capture different features:
# <img src="https://thatindiandude.github.io/images/filters.png" style="height: 75%; width: 75%;">

# %% [markdown]
# Besides the convolutional layer, another major change of the convolutional neural network is the adding of pooling layers. A pooling layer reduce a $n\times m$ (often called kernal size) image patch into a single value to make the network less sensitive to the spatial location.
#
# <img src="https://thatindiandude.github.io/images/pooling.png" style="height: 75%; width: 75%;">

# %%
data = mx.symbol.Variable('data')
# first conv layer
conv1 = mx.sym.Convolution(data=data, kernel=(5,5), num_filter=20)
tanh1 = mx.sym.Activation(data=conv1, act_type="tanh")
pool1 = mx.sym.Pooling(data=tanh1, pool_type="max", kernel=(2,2), stride=(2,2))
# second conv layer
conv2 = mx.sym.Convolution(data=pool1, kernel=(5,5), num_filter=50)
tanh2 = mx.sym.Activation(data=conv2, act_type="tanh")
pool2 = mx.sym.Pooling(data=tanh2, pool_type="max", kernel=(2,2), stride=(2,2))
# first fullc layer
flatten = mx.sym.Flatten(data=pool2)
fc1 = mx.symbol.FullyConnected(data=flatten, num_hidden=500)
tanh3 = mx.sym.Activation(data=fc1, act_type="tanh")
# second fullc
fc2 = mx.sym.FullyConnected(data=tanh3, num_hidden=10)
# softmax loss
lenet = mx.sym.SoftmaxOutput(data=fc2, name='softmax')
mx.viz.plot_network(symbol=lenet, shape=shape)

# %% [markdown]
# Note that LeNet is more complex than the previous multilayer perceptron, so we use GPU instead of CPU for training.

# %%
# @@@ AUTOTEST_OUTPUT_IGNORED_CELL
model = mx.model.FeedForward(
    #ctx = mx.gpu(0),     # use GPU 0 for training, others are same as before
    symbol = lenet,       
    num_epoch = 10,     
    learning_rate = 0.1)
model.fit(
    X=train_iter,  
    eval_data=val_iter, 
    batch_end_callback = mx.callback.Speedometer(batch_size, 200)
) 
assert model.score(val_iter) > 0.98, "Low validation accuracy."
# Out:
# /Users/jon/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [200]	Speed: 1504.34 samples/sec	accuracy=0.109300
# INFO:root:Epoch[0] Batch [400]	Speed: 1506.73 samples/sec	accuracy=0.112200
# INFO:root:Epoch[0] Batch [600]	Speed: 1505.87 samples/sec	accuracy=0.114100
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=39.937
# INFO:root:Epoch[0] Validation-accuracy=0.113500
# INFO:root:Epoch[1] Batch [200]	Speed: 1486.82 samples/sec	accuracy=0.329600
# INFO:root:Epoch[1] Batch [400]	Speed: 1390.15 samples/sec	accuracy=0.880450
# INFO:root:Epoch[1] Batch [600]	Speed: 1475.12 samples/sec	accuracy=0.928050
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=41.435
# INFO:root:Epoch[1] Validation-accuracy=0.944700
# INFO:root:Epoch[2] Batch [200]	Speed: 1472.35 samples/sec	accuracy=0.948950
# INFO:root:Epoch[2] Batch [400]	Speed: 1464.86 samples/sec	accuracy=0.962650
# INFO:root:Epoch[2] Batch [600]	Speed: 1480.19 samples/sec	accuracy=0.964100
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=40.787
# INFO:root:Epoch[2] Validation-accuracy=0.971200
# INFO:root:Epoch[3] Batch [200]	Speed: 1403.09 samples/sec	accuracy=0.970950
# INFO:root:Epoch[3] Batch [400]	Speed: 1412.16 samples/sec	accuracy=0.976400
# INFO:root:Epoch[3] Batch [600]	Speed: 1490.91 samples/sec	accuracy=0.975750
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=41.869
# INFO:root:Epoch[3] Validation-accuracy=0.980300
# INFO:root:Epoch[4] Batch [200]	Speed: 1531.49 samples/sec	accuracy=0.978300
# INFO:root:Epoch[4] Batch [400]	Speed: 1518.89 samples/sec	accuracy=0.983050
# INFO:root:Epoch[4] Batch [600]	Speed: 1478.82 samples/sec	accuracy=0.982050
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=39.794
# INFO:root:Epoch[4] Validation-accuracy=0.984000
# INFO:root:Epoch[5] Batch [200]	Speed: 1510.15 samples/sec	accuracy=0.982250
# INFO:root:Epoch[5] Batch [400]	Speed: 1502.14 samples/sec	accuracy=0.986150
# INFO:root:Epoch[5] Batch [600]	Speed: 1520.91 samples/sec	accuracy=0.985300
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=39.748
# INFO:root:Epoch[5] Validation-accuracy=0.986500
# INFO:root:Epoch[6] Batch [200]	Speed: 1476.12 samples/sec	accuracy=0.985900
# INFO:root:Epoch[6] Batch [400]	Speed: 1317.85 samples/sec	accuracy=0.988700
# INFO:root:Epoch[6] Batch [600]	Speed: 1452.47 samples/sec	accuracy=0.987950
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=42.532
# INFO:root:Epoch[6] Validation-accuracy=0.987700
# INFO:root:Epoch[7] Batch [200]	Speed: 1503.40 samples/sec	accuracy=0.987950
# INFO:root:Epoch[7] Batch [400]	Speed: 1481.22 samples/sec	accuracy=0.990450
# INFO:root:Epoch[7] Batch [600]	Speed: 1494.06 samples/sec	accuracy=0.990100
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=40.230
# INFO:root:Epoch[7] Validation-accuracy=0.988000
# INFO:root:Epoch[8] Batch [200]	Speed: 1477.10 samples/sec	accuracy=0.989850
# INFO:root:Epoch[8] Batch [400]	Speed: 1388.13 samples/sec	accuracy=0.991300
# INFO:root:Epoch[8] Batch [600]	Speed: 1441.73 samples/sec	accuracy=0.991100
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=41.858
# INFO:root:Epoch[8] Validation-accuracy=0.989000
# INFO:root:Epoch[9] Batch [200]	Speed: 1446.61 samples/sec	accuracy=0.990500
# INFO:root:Epoch[9] Batch [400]	Speed: 1334.40 samples/sec	accuracy=0.992200
# INFO:root:Epoch[9] Batch [600]	Speed: 1452.61 samples/sec	accuracy=0.991750
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=42.618
# INFO:root:Epoch[9] Validation-accuracy=0.989500

# %% [markdown]
# Note that, with the same hyper-parameters, LeNet achieves 98.7% validation accuracy, which improves on the previous multilayer perceptron accuracy of 96.6%.
#
# Because we rewrite the model parameters in `mod`, now we can try the previous digit recognition box again to check if or not the new CNN model improves the classification accuracy.
